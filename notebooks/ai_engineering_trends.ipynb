# %% [markdown]
# <a href="https://colab.research.google.com/github/rodiwaa/learnings-pocs/blob/main/notebooks/ai_engineering_trends.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Find weekly trends for AI Engrr Jobs
# This is to help potential ai-engineer job seekers stay updted with new skills being asked for in ai-engineering roles.
#
# - scan new job listings weekly
# - map imp keywords, tech stack for new jobs per week.
# - dashboard to show new trends
