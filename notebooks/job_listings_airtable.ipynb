# %% [markdown]
# <a href="https://colab.research.google.com/github/rodiwaa/learnings-pocs/blob/main/notebooks/job_listings_airtable.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Search job listings and research company
# - This project looks up new job listings as per keywords
# - It will then research company prolfile with following points
#   - insights from latest engineering blog
#   - insights from latest tweets
#   - important products from company page
#   - important POCs from linkedin
#   - future todos
#     - [planned]
