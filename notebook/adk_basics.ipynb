# %% [markdown]
# <a href="https://colab.research.google.com/github/rodiwaa/learnings-pocs/blob/main/notebook/adk_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# plan
# - create simple greetin_agent
# - create tool to print hello or hey
# - wrap in functool
# - attach to greeting_agent
# - print
# - stream

# %%
! pip install google-adk google-generativeai

# %%
from google.adk.agents import Agent
from google.adk.tools import google_search
from google.adk.runners import Runner
from google.adk.sessions import InMemorySessionService, Session
from google.genai.types import Content, Part
from IPython.display import display, Markdown

# %%
from getpass import getpass
# from google.generativeai import genai
import google.generativeai as genai
import os

api_key = getpass("enter google api_key: ")

genai.configure(api_key=api_key)

os.environ["GOOGLE_API_KEY"] = api_key

print("google api key set")
# Out:
# enter google api_key: ··········
# google api key set

# %%
# agent

# session

# userid

# runner

# run

# %%
# --- Agent Definition ---

def create_day_trip_agent():
    """Create the Spontaneous Day Trip Generator agent"""
    return Agent(
        name="day_trip_agent",
        model="gemini-2.5-flash",
        description="Agent specialized in generating spontaneous full-day itineraries based on mood, interests, and budget.",
        instruction="""
        You are the "Spontaneous Day Trip" Generator 🚗 - a specialized AI assistant that creates engaging full-day itineraries.

        Your Mission:
        Transform a simple mood or interest into a complete day-trip adventure with real-time details, while respecting a budget.

        Guidelines:
        1. **Budget-Aware**: Pay close attention to budget hints like 'cheap', 'affordable', or 'splurge'. Use Google Search to find activities (free museums, parks, paid attractions) that match the user's budget.
        2. **Full-Day Structure**: Create morning, afternoon, and evening activities.
        3. **Real-Time Focus**: Search for current operating hours and special events.
        4. **Mood Matching**: Align suggestions with the requested mood (adventurous, relaxing, artsy, etc.).

        RETURN itinerary in MARKDOWN FORMAT with clear time blocks and specific venue names.
        """,
        tools=[google_search]
    )

day_trip_agent = create_day_trip_agent()
print(f"🧞 Agent '{day_trip_agent.name}' is created and ready for adventure!")
# Out:
# 🧞 Agent 'day_trip_agent' is created and ready for adventure!

# %%
async def run_agent_query(agent: Agent, query: str, session: Session, user_id: str, is_router: bool = False):
    """Initializes a runner and executes a query for a given agent and session."""
    print(f"\n🚀 Running query for agent: '{agent.name}' in session: '{session.id}'...")

    runner = Runner(
        agent=agent,
        session_service=session_service,
        app_name=agent.name
    )
    final_response = ""
    try:
       async for event in runner.run_async(
            user_id=user_id,
            session_id=session.id,
            new_message=Content(parts=[Part(text=query)], role="user")
        ):

         if event.is_final_response():
                final_response = event.content.parts[0].text
    except Exception as e:
      final_response = f"An error occurred: {e}"

    print("\n" + "-"*50)
    print("✅ Final Response:")
    display(Markdown(final_response))
    print("-"*50 + "\n")

session_service = InMemorySessionService()
my_user_id = "adk_adventurer_001"

# %%
async def run_day_trip_genie():
    # Create a new, single-use session for this query
    day_trip_session = await session_service.create_session(
        app_name=day_trip_agent.name,
        user_id=my_user_id
    )

    # Note the new budget constraint in the query!
    query = "Plan a relaxing and artsy day trip near Sunnyvale, CA. Keep it affordable!"
    print(f"🗣️ User Query: '{query}'")

    await run_agent_query(day_trip_agent, query, day_trip_session, my_user_id)

await run_day_trip_genie()
# Out:
# 🗣️ User Query: 'Plan a relaxing and artsy day trip near Sunnyvale, CA. Keep it affordable!'
#
# 🚀 Running query for agent: 'day_trip_agent' in session: 'ad75ead0-c3bb-4174-a818-f18258deb802'...
#
# --------------------------------------------------
# ✅ Final Response:
# Here's a relaxing and artsy day trip itinerary near Sunnyvale, CA, designed to be affordable and enjoyable for today, Friday, January 23, 2026:
#
# ## Relaxing & Artsy Day Trip Near Sunnyvale, CA (Affordable)
#
# This itinerary focuses on free art experiences and serene outdoor spaces to ensure a peaceful and culturally enriching day without breaking the bank.
#
# ---
#
# ### **Morning: Immerse in Art at Stanford University**
#
# *   **11:00 AM - 1:30 PM: Cantor Arts Center, Stanford University, Palo Alto**
#     Begin your day with a visit to the renowned Cantor Arts Center at Stanford University. Admission is always free, making it a fantastic and affordable cultural experience. The museum houses diverse collections spanning various periods and cultures, including Rodin sculptures, African art, and contemporary works. Take your time to wander through the galleries and enjoy the peaceful atmosphere. The center is open until 6:00 PM on Fridays.
#     *   **Cost:** Free admission.
#     *   **Parking:** Paid parking is available on the Stanford campus, usually managed via the ParkMobile app.
#
# ### **Lunch: Relaxing Picnic on Campus**
#
# *   **1:30 PM - 2:30 PM: Picnic at The Oval or a Campus Green, Stanford University**
#     To keep costs down and enjoy the beautiful surroundings, pack a picnic lunch to savor on Stanford's iconic Oval or one of the many serene green spaces around the campus. This offers a tranquil setting to relax and reflect on the art you've seen.
#
# ### **Afternoon: Outdoor Art & Scenic Stroll**
#
# *   **2:30 PM - 4:30 PM: Rodin Sculpture Garden & Campus Walk, Stanford University**
#     After lunch, continue your artsy and relaxing journey by exploring the outdoor Rodin Sculpture Garden, located just outside the Cantor Arts Center. Then, take a leisurely stroll through the picturesque Stanford University campus, admiring the architecture and academic ambiance. Many of Stanford's outdoor spaces offer a calming environment.
# *   **4:30 PM - 5:30 PM: Downtown Palo Alto Public Art Exploration**
#     Head into downtown Palo Alto, a charming area with a commitment to public art. The City of Palo Alto has approximately 100 permanently sited public artworks. You can take a self-guided walk to discover various sculptures, murals, and installations. A Public Art Collection Map is available to help you navigate and find pieces near your location.
#     *   **Cost:** Free.
#     *   **Parking:** Metered street parking or public garages are available in downtown Palo Alto.
#
# ### **Evening: Engaging Gallery & Downtown Vibe**
#
# *   **6:00 PM - 7:00 PM: KALEID Gallery, San Jose**
#     Conclude your artsy day with a visit to KALEID Gallery in downtown San Jose. This independent gallery features a wide range of local artists and offers free admission. On Fridays, it's open until 7:00 PM, providing a great opportunity to explore contemporary local art.
#     *   **Cost:** Free admission.
#     *   **Parking:** Metered street parking and paid garages are available in downtown San Jose.
# *   **7:00 PM onwards: Relaxed Evening in San Jose's SoFA District**
#     After visiting KALEID Gallery, enjoy the relaxed, creative atmosphere of San Jose's SoFA (South First Area) District. This area is known for its arts and culture scene. You can find an affordable spot for a coffee, dessert, or a light bite to wind down your day. Consider a leisurely walk to take in the evening ambiance and any additional public art you might encounter.
# --------------------------------------------------
